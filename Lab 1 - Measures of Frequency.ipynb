# %% [markdown]
# ###**Q1: Load drug_dataset.csv dataset**

# %% [markdown]
# ### **Q2: Find the frequency for each Categorical Feature**

# %%
# Out:
# F     96
# M    104
# Name: Sex, dtype: int64

# %%
# Out:
# NORMAL    59
# LOW       64
# HIGH      77
# Name: BP, dtype: int64

# %%
# Out:
# NORMAL     97
# HIGH      103
# Name: Cholesterol, dtype: int64

# %%
# Out:
# drugC    16
# drugB    16
# drugA    23
# drugX    54
# DrugY    91
# Name: Drug, dtype: int64

# %% [markdown]
# ### **Q3: Calculate the relative frequency for each Categorical Feature**

# %%
# Out:
# F    48.0
# M    52.0
# Name: Sex, dtype: float64

# %%
# Out:
# NORMAL    29.5
# LOW       32.0
# HIGH      38.5
# Name: BP, dtype: float64

# %%
# Out:
# NORMAL    48.5
# HIGH      51.5
# Name: Cholesterol, dtype: float64

# %%
# Out:
# drugC     8.0
# drugB     8.0
# drugA    11.5
# drugX    27.0
# DrugY    45.5
# Name: Drug, dtype: float64

# %% [markdown]
# ### **Q4: Calculate the cumulative frequency for Categorical Feature**
#
# > Hint: use .cumsum()

# %%
# Out:
# F     96
# M    200
# Name: Sex, dtype: int64

# %%
# Out:
# NORMAL     59
# LOW       123
# HIGH      200
# Name: BP, dtype: int64

# %%
# Out:
# NORMAL     97
# HIGH      200
# Name: Cholesterol, dtype: int64

# %%
# Out:
# drugC     16
# drugB     32
# drugA     55
# drugX    109
# DrugY    200
# Name: Drug, dtype: int64

# %% [markdown]
# ### **Q5: Calculate the cumulative relative frequency Categorical Feature**

# %%
# Out:
# F     48.0
# M    100.0
# Name: Sex, dtype: float64

# %%
# Out:
# NORMAL     29.5
# LOW        61.5
# HIGH      100.0
# Name: BP, dtype: float64

# %%
# Out:
# NORMAL     48.5
# HIGH      100.0
# Name: Cholesterol, dtype: float64

# %%
# Out:
# drugC      8.0
# drugB     16.0
# drugA     27.5
# drugX     54.5
# DrugY    100.0
# Name: Drug, dtype: float64

# %% [markdown]
# ### **Q6: EDA**

# %% [markdown]
# **Q6.1: Plot the Ratio of Each Type of Drug Types to Total Types**

# %% [markdown]
# **Q6.2: Plot Number of Drug Type by Gender of patient**

# %% [markdown]
# **Q6.3: Plot Sodium to potassium Ration in Blood**
